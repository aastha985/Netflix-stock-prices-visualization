# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix-stocks-data.csv')
df['Date']= pd.to_datetime(df['Date'])
df['year'] = pd.DatetimeIndex(df['Date']).year

# %%
df.head()
# Out:
#         Date  Close/Last    Volume      Open      High         Low  year
# 0 2020-07-17     $492.99  24991350   $494.87   $503.59     $484.14  2020
# 1 2020-07-16     $527.39  24498990   $526.48   $535.54   $504.3627  2020
# 2 2020-07-15     $523.26  10066650    $516.3      $529     $510.18  2020
# 3 2020-07-14     $524.88  15083300   $517.08    $525.5     $490.49  2020
# 4 2020-07-13      $525.5  18399020   $567.98   $575.37     $520.96  2020

# %%
pd.set_option('mode.chained_assignment', None)
arr_convert = [' Open',' High',' Low',' Close/Last']
for ind in df.index:
    for j in arr_convert:
        index=df[j][ind].find("$")
        if index!=-1:
            df[j][ind]= df[j][ind][index+1:]

# %%
for i in arr_convert:
    df[i]=pd.to_numeric(df[i])

# %%
a_plot=sns.relplot(x="Date", y=" Open", data=df,kind="line");

# %%
df.head()
# Out:
#         Date   Close/Last    Volume    Open    High       Low  year
# 0 2020-07-17       492.99  24991350  494.87  503.59  484.1400  2020
# 1 2020-07-16       527.39  24498990  526.48  535.54  504.3627  2020
# 2 2020-07-15       523.26  10066650  516.30  529.00  510.1800  2020
# 3 2020-07-14       524.88  15083300  517.08  525.50  490.4900  2020
# 4 2020-07-13       525.50  18399020  567.98  575.37  520.9600  2020

# %%
a_plot=sns.relplot(x="Date", y=" Open", data=df,kind='line',sort=False);

# %%
a_plot=sns.relplot(x="year", y=" High", data=df,kind='line',sort=False);

# %%
a_plot=sns.relplot(x="Date", y=" Low", data=df,kind='line');

# %%
a_plot=sns.relplot(x="Date", y=" Close/Last", data=df,kind='line',sort=False);

# %%
a_plot=sns.relplot(x="Date", y=" Volume", data=df,kind='line');

# %%
sns.stripplot(x="year", y=" Open", data=df)

# %%
sns.violinplot(x="year", y=" High", data=df,inner=None, color=".8")
sns.stripplot(x="year", y=" High", data=df)

# %%
sns.swarmplot(x="year", y=" High", data=df)

# %%
sns.boxplot(x="year", y=" High", data=df)

# %%
sns.violinplot(x="year", y=" High", data=df)

# %%
sns.pointplot(x="year", y=" High",data=df)

# %%
sns.pointplot(x="year", y=" Low",data=df)

# %%
sns.pointplot(x="year", y=" Open",data=df)

# %%
sns.pointplot(x="year", y=" Close/Last",data=df)

# %%
sns.pointplot(x="year", y=" Volume",data=df)

# %%
sns.barplot(x="year", y=" High", data=df)

# %%
sns.jointplot(x="year", y=" High", data=df);

# %%
sns.jointplot(x=" High",y=" Low",data=df)

# %%
sns.jointplot(x=" High",y="year",data=df)

# %%
with sns.axes_style("white"):
    sns.jointplot(x=df['year'], y=df[' High'], kind="hex", color="k");

# %%
sns.jointplot(x=df['year'], y=df[' High'], data=df, kind="kde");

# %%
sns.jointplot(x=df[' Low'], y=df[' High'], data=df, kind="kde");

# %%
sns.jointplot(x=df['year'], y=df[' Volume'], data=df, kind="kde");
